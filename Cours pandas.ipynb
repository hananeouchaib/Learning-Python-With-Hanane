# %% [markdown]
# <a href="https://colab.research.google.com/github/hananeouchaib/Learning-Python-With-Hanane/blob/main/Cours%20pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Cours pandas**

# %%
# pandas permet de manipuler, analyser et nettoyer les données
import pandas as pd

# %%
# lire le fichier csv et l'afficher dans une table
table = pd.read_csv('/content/Empl-Depart.csv')

# %%
table
# Out:
#      First Name    Last Name     Email        Phone Number   Hire Date  \
# 0        Steven         King     SKING        515.123.4567  10/10/2009
# 1         Neena      Kochhar  NKOCHHAR        515.123.4568   1/15/2012
# 2           Lex      De Haan   LDEHAAN        515.123.4569    5/9/2015
# 3     Alexander       Hunold   AHUNOLD        590.423.4567   4/28/2012
# 4         Bruce        Ernst    BERNST        590.423.4568   9/13/2013
# 5         David       Austin   DAUSTIN        590.423.4569  10/19/2019
# 6         Valli    Pataballa  VPATABAL        590.423.4560   5/31/2020
# 7         Diana      Lorentz  DLORENTZ        590.423.5567    6/2/2021
# 8         Nancy    Greenberg  NGREENBE        515.124.4569  12/10/2016
# 9        Daniel       Faviet   DFAVIET        515.124.4169   12/9/2016
# 10         John         Chen     JCHEN        515.124.4269   1/22/2020
# 11       Ismael      Sciarra  ISCIARRA        515.124.4369   1/24/2020
# ...

# %%
# afficher le type de la table
type(table)
# Out:
# pandas.core.frame.DataFrame

# %%
# afficher le nombre de lignes et de colonnes dans la table
table.shape
# Out:
# (50, 10)

# %%
# afficher les colonnes de la table
table.columns
# Out:
# Index(['First Name', 'Last Name', 'Email', 'Phone Number', 'Hire Date', 'Job ',
#        'Salary', 'Commission Percent', 'Manager', 'Department'],
#       dtype='object')

# %%
# afficher des informations sur les colonnes
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   First Name          50 non-null     object
#  1   Last Name           50 non-null     object
#  2   Email               50 non-null     object
#  3   Phone Number        50 non-null     object
#  4   Hire Date           50 non-null     object
#  5   Job                 50 non-null     object
#  6   Salary              50 non-null     object
#  7   Commission Percent  5 non-null      float64
#  8   Manager             49 non-null     object
#  9   Department          50 non-null     object
# dtypes: float64(1), object(9)
# memory usage: 4.0+ KB

# %%
# afficher les 10 premières lignes de la table
table.head(10)
# Out:
#   First Name  Last Name     Email  Phone Number   Hire Date  \
# 0     Steven       King     SKING  515.123.4567  10/10/2009
# 1      Neena    Kochhar  NKOCHHAR  515.123.4568   1/15/2012
# 2        Lex    De Haan   LDEHAAN  515.123.4569    5/9/2015
# 3  Alexander     Hunold   AHUNOLD  590.423.4567   4/28/2012
# 4      Bruce      Ernst    BERNST  590.423.4568   9/13/2013
# 5      David     Austin   DAUSTIN  590.423.4569  10/19/2019
# 6      Valli  Pataballa  VPATABAL  590.423.4560   5/31/2020
# 7      Diana    Lorentz  DLORENTZ  590.423.5567    6/2/2021
# 8      Nancy  Greenberg  NGREENBE  515.124.4569  12/10/2016
# 9     Daniel     Faviet   DFAVIET  515.124.4169   12/9/2016
#
#                             Job   Salary  Commission Percent    Manager  \
# 0                      President  24,000                 NaN        NaN
# 1  Administration Vice President  17,000                 NaN     Steven
# 2  Administration Vice President  17,000                 NaN     Steven
# ...

# %%
# afficher les 10 dernières lignes de la table
table.tail(10)
# Out:
#    First Name  Last Name     Email        Phone Number  Hire Date  \
# 40     Joshua      Patel    JPATEL        650.121.1834  7/30/2020
# 41     Trenna       Rajs     TRAJS        650.121.8009   2/9/2018
# 42     Curtis     Davies   CDAVIES        650.121.2994  5/25/2019
# 43    Randall      Matos    RMATOS        650.121.2874   7/8/2020
# 44      Peter     Vargas   PVARGAS        650.121.2004  11/1/2020
# 45       John    Russell   JRUSSEL  011.44.1344.429268  1/25/2019
# 46      Karen   Partners  KPARTNER  011.44.1344.467268   5/1/2019
# 47    Alberto  Errazuriz  AERRAZUR  011.44.1344.429278   7/4/2019
# 48     Gerald  Cambrault  GCAMBRAU  011.44.1344.619268   2/7/2022
# 49      Eleni    Zlotkey  EZLOTKEY  011.44.1344.429018  5/24/2022
#
#              Job   Salary  Commission Percent Manager  Department
# 40    Stock Clerk   2,500                 NaN  Shanta    RESEARCH
# 41    Stock Clerk   3,500                 NaN   Kevin  ACCOUNTING
# ...

# %%
# remplacer les virgules par rien dans la colonne Salary
table['Salary'] = table['Salary'].replace(',','', regex=True)

# %%
# convertir le type object de la colonne Salary en int
table['Salary'] = pd.to_numeric(table['Salary'])

# %%
# afficher une seule colonne
S = table['Salary']
S
# Out:
# 0     24000
# 1     17000
# 2     17000
# 3      9000
# 4      6000
# 5      4800
# 6      4800
# 7      4200
# 8     12000
# 9      9000
# 10     8200
# 11     7700
# 12     7800
# 13     6900
# 14    11000
# 15     3100
# 16     2900
# 17     2800
# 18     2600
# 19     2500
# 20     8000
# 21     8200
# 22     7900
# 23     6500
# 24     5800
# 25     3200
# 26     2700
# 27     2400
# 28     2200
# 29     3300
# 30     2800
# 31     2500
# 32     2100
# 33     3300
# 34     2900
# 35     2400
# 36     2200
# 37     3600
# 38     3200
# 39     2700
# 40     2500
# 41     3500
# 42     3100
# 43     2600
# 44     2500
# 45    14000
# 46    13500
# 47    12000
# 48    11000
# 49    10500
# Name: Salary, dtype: int64

# %%
# calculer la moyenne de la colonne S
S.mean()
# Out:
# 6328.0

# %%
S.describe()
# Out:
# count       50.000000
# mean      6328.000000
# std       4811.679668
# min       2100.000000
# 25%       2725.000000
# 50%       3900.000000
# 75%       8200.000000
# max      24000.000000
# Name: Salary, dtype: float64

# %%
table.columns
# Out:
# Index(['First Name', 'Last Name', 'Email', 'Phone Number', 'Hire Date', 'Job ',
#        'Salary', 'Commission Percent', 'Manager', 'Department'],
#       dtype='object')

# %%
info_emp = table[['First Name', 'Last Name', 'Department', 'Phone Number','Salary']]
info_emp
# Out:
#      First Name    Last Name  Department        Phone Number  Salary
# 0        Steven         King  ACCOUNTING        515.123.4567   24000
# 1         Neena      Kochhar    RESEARCH        515.123.4568   17000
# 2           Lex      De Haan       SALES        515.123.4569   17000
# 3     Alexander       Hunold       SALES        590.423.4567    9000
# 4         Bruce        Ernst       SALES        590.423.4568    6000
# 5         David       Austin       SALES        590.423.4569    4800
# 6         Valli    Pataballa       SALES        590.423.4560    4800
# 7         Diana      Lorentz       SALES        590.423.5567    4200
# 8         Nancy    Greenberg  ACCOUNTING        515.124.4569   12000
# 9        Daniel       Faviet    RESEARCH        515.124.4169    9000
# 10         John         Chen    RESEARCH        515.124.4269    8200
# 11       Ismael      Sciarra    RESEARCH        515.124.4369    7700
# 12  Jose Manuel        Urman    RESEARCH        515.124.4469    7800
# ...

# %%
info_emp.describe()
# Out:
#              Salary
# count     50.000000
# mean    6328.000000
# std     4811.679668
# min     2100.000000
# 25%     2725.000000
# 50%     3900.000000
# 75%     8200.000000
# max    24000.000000

# %%
info_emp['Department']
# Out:
# 0     ACCOUNTING
# 1       RESEARCH
# 2          SALES
# 3          SALES
# 4          SALES
# 5          SALES
# 6          SALES
# 7          SALES
# 8     ACCOUNTING
# 9       RESEARCH
# 10      RESEARCH
# 11      RESEARCH
# 12      RESEARCH
# 13    ACCOUNTING
# 14    ACCOUNTING
# 15      RESEARCH
# 16         SALES
# 17         SALES
# 18         SALES
# 19         SALES
# 20         SALES
# 21         SALES
# 22    ACCOUNTING
# 23      RESEARCH
# 24      RESEARCH
# 25      RESEARCH
# 26      RESEARCH
# 27    ACCOUNTING
# 28    ACCOUNTING
# 29      RESEARCH
# 30         SALES
# 31         SALES
# 32         SALES
# 33         SALES
# 34         SALES
# 35         SALES
# 36    ACCOUNTING
# 37      RESEARCH
# 38      RESEARCH
# 39      RESEARCH
# 40      RESEARCH
# 41    ACCOUNTING
# 42    ACCOUNTING
# 43      RESEARCH
# 44         SALES
# 45         SALES
# 46         SALES
# 47         SALES
# 48         SALES
# 49         SALES
# Name: Department, dtype: object

# %%
info_emp['Department'].value_counts()
# Out:
# SALES         24
# RESEARCH      16
# ACCOUNTING    10
# Name: Department, dtype: int64

# %% [markdown]
# # **loc et iloc**

# %%
# affiche toutes les valeurs de la 4ème ligne
table.iloc[4]
# Out:
# First Name                   Bruce
# Last Name                    Ernst
# Email                       BERNST
# Phone Number          590.423.4568
# Hire Date                9/13/2013
# Job                     Programmer
# Salary                        6000
# Commission Percent             NaN
# Manager                  Alexander
# Department                   SALES
# Name: 4, dtype: object

# %%
# affiche toutes les valeurs des lignes entre 10 et 19
table.iloc[10:20]
# Out:
#      First Name   Last Name     Email  Phone Number   Hire Date  \
# 10         John        Chen     JCHEN  515.124.4269   1/22/2020
# 11       Ismael     Sciarra  ISCIARRA  515.124.4369   1/24/2020
# 12  Jose Manuel       Urman   JMURMAN  515.124.4469   6/30/2020
# 13         Luis        Popp     LPOPP  515.124.4567    4/1/2022
# 14          Den    Raphaely  DRAPHEAL  515.127.4561    4/1/2017
# 15    Alexander        Khoo     AKHOO  515.127.4562   9/10/2017
# 16       Shelli       Baida    SBAIDA  515.127.4563   4/18/2020
# 17        Sigal      Tobias   STOBIAS  515.127.4564  11/17/2019
# 18          Guy      Himuro   GHIMURO  515.127.4565   3/10/2021
# 19        Karen  Colmenares  KCOLMENA  515.127.4566   12/3/2021
#
#                   Job   Salary  Commission Percent Manager  Department
# 10          Accountant    8200                 NaN   Nancy    RESEARCH
# 11          Accountant    7700                 NaN   Nancy    RESEARCH
# ...

# %%
# affiche les valeurs de la colonne 0 des lignes 10 jusqu'à 19
table.iloc[10:20,0]
# Out:
# 10           John
# 11         Ismael
# 12    Jose Manuel
# 13           Luis
# 14            Den
# 15      Alexander
# 16         Shelli
# 17          Sigal
# 18            Guy
# 19          Karen
# Name: First Name, dtype: object

# %%
# affiche les valeurs des deux colonnes salary et manager pour les lignes 10 jusqu'à 20 inclu
table.loc[10:20,['Salary','Manager']]
# Out:
#     Salary Manager
# 10    8200   Nancy
# 11    7700   Nancy
# 12    7800   Nancy
# 13    6900   Nancy
# 14   11000  Steven
# 15    3100     Den
# 16    2900     Den
# 17    2800     Den
# 18    2600     Den
# 19    2500     Den
# 20    8000  Steven

# %% [markdown]
# # **Filtrage**

# %%
table
# Out:
#      First Name    Last Name     Email        Phone Number   Hire Date  \
# 0        Steven         King     SKING        515.123.4567  10/10/2009
# 1         Neena      Kochhar  NKOCHHAR        515.123.4568   1/15/2012
# 2           Lex      De Haan   LDEHAAN        515.123.4569    5/9/2015
# 3     Alexander       Hunold   AHUNOLD        590.423.4567   4/28/2012
# 4         Bruce        Ernst    BERNST        590.423.4568   9/13/2013
# 5         David       Austin   DAUSTIN        590.423.4569  10/19/2019
# 6         Valli    Pataballa  VPATABAL        590.423.4560   5/31/2020
# 7         Diana      Lorentz  DLORENTZ        590.423.5567    6/2/2021
# 8         Nancy    Greenberg  NGREENBE        515.124.4569  12/10/2016
# 9        Daniel       Faviet   DFAVIET        515.124.4169   12/9/2016
# 10         John         Chen     JCHEN        515.124.4269   1/22/2020
# 11       Ismael      Sciarra  ISCIARRA        515.124.4369   1/24/2020
# ...

# %%
sales = (table['Department']=='SALES')
sales
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# Name: Department, dtype: bool

# %%
table.loc[sales,['First Name','Last Name','Department']]
# Out:
#    First Name   Last Name Department
# 2         Lex     De Haan      SALES
# 3   Alexander      Hunold      SALES
# 4       Bruce       Ernst      SALES
# 5       David      Austin      SALES
# 6       Valli   Pataballa      SALES
# 7       Diana     Lorentz      SALES
# 16     Shelli       Baida      SALES
# 17      Sigal      Tobias      SALES
# 18        Guy      Himuro      SALES
# 19      Karen  Colmenares      SALES
# 20    Matthew       Weiss      SALES
# 21       Adam       Fripp      SALES
# 30      Mozhe    Atkinson      SALES
# 31      James      Marlow      SALES
# 32         TJ       Olson      SALES
# 33      Jason      Mallin      SALES
# 34    Michael      Rogers      SALES
# 35         Ki         Gee      SALES
# 44      Peter      Vargas      SALES
# 45       John     Russell      SALES
# 46      Karen    Partners      SALES
# 47    Alberto   Errazuriz      SALES
# 48     Gerald   Cambrault      SALES
# 49      Eleni     Zlotkey      SALES

# %%
table.loc[-sales,['First Name','Last Name','Department']]
# Out:
#      First Name    Last Name  Department
# 0        Steven         King  ACCOUNTING
# 1         Neena      Kochhar    RESEARCH
# 8         Nancy    Greenberg  ACCOUNTING
# 9        Daniel       Faviet    RESEARCH
# 10         John         Chen    RESEARCH
# 11       Ismael      Sciarra    RESEARCH
# 12  Jose Manuel        Urman    RESEARCH
# 13         Luis         Popp  ACCOUNTING
# 14          Den     Raphaely  ACCOUNTING
# 15    Alexander         Khoo    RESEARCH
# 22        Payam     Kaufling  ACCOUNTING
# 23       Shanta      Vollman    RESEARCH
# 24        Kevin      Mourgos    RESEARCH
# 25        Julia        Nayer    RESEARCH
# 26        Irene  Mikkilineni    RESEARCH
# 27        James       Landry  ACCOUNTING
# 28       Steven       Markle  ACCOUNTING
# 29        Laura       Bissot    RESEARCH
# 36        Hazel   Philtanker  ACCOUNTING
# 37       Renske       Ladwig    RESEARCH
# 38      Stephen       Stiles    RESEARCH
# 39         John          Seo    RESEARCH
# ...
